# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./trained_models/history_dropout_global.csv')

# %%
plt.plot(df.index, df['Train Loss'], label='Train')
plt.plot(df.index, df['Val Loss'], label='Test')
plt.legend()
plt.show()
